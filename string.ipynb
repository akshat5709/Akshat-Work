# %%
name = "akshat srivastava"
i = 1
for i in range(10):
    print(i,name)
    print(name[0:6])
# Out:
# 0 akshat srivastava
# akshat
# 1 akshat srivastava
# akshat
# 2 akshat srivastava
# akshat
# 3 akshat srivastava
# akshat
# 4 akshat srivastava
# akshat
# 5 akshat srivastava
# akshat
# 6 akshat srivastava
# akshat
# 7 akshat srivastava
# akshat
# 8 akshat srivastava
# akshat
# 9 akshat srivastava
# akshat

# %%
a = "hey"
print(a*3)
# Out:
# heyheyhey
