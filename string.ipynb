# %%
name = "akshat srivastava"
i = 1
for i in range(10):
    print(i,name)
    print(name[0:6])
# Out:
# 0 akshat srivastava
# akshat
# 1 akshat srivastava
# akshat
# 2 akshat srivastava
# akshat
# 3 akshat srivastava
# akshat
# 4 akshat srivastava
# akshat
# 5 akshat srivastava
# akshat
# 6 akshat srivastava
# akshat
# 7 akshat srivastava
# akshat
# 8 akshat srivastava
# akshat
# 9 akshat srivastava
# akshat

# %%
a = "hey"
print(a*3)
# Out:
# heyheyhey

# %%
poem = """jonny jonny yes papa
         eating sugar no papa
         teling a lie no papa
         open your mouth hahaha"""
print(poem)
# Out:
# jonny jonny yes papa
#          eating sugar no papa
#          teling a lie no papa
#          open your mouth hahaha

# %%
poem.splitlines()
# Out:
# ['jonny jonny yes papa',
#  '         eating sugar no papa',
#  '         teling a lie no papa',
#  '         open your mouth hahaha']

# %%
p = poem.replace('jonny','sameer').replace('sugar','mutton').replace('open your mouth','open your chaddi')

print(p)
# Out:
# sameer sameer yes papa
#          eating mutton no papa
#          teling a lie no papa
#          open your chaddi hahaha

# %%
p.find('chaddi')
# Out:
# 103

# %%
url = ['www','google','com']
'.' .join(url)
# Out:
# 'www.google.com'

# %%
x = 'beautiful'
x.upper()
# Out:
# 'BEAUTIFUL'

# %%
x = 'BEAUTIFUL'
x.lower()
# Out:
# 'beautiful'

# %%
x = 'beautiful'
x.capitalize()
# Out:
# 'Beautiful'

# %%
a = 'you are fool'
a.split()
# Out:
# ['you', 'are', 'fool']

# %% [markdown]
# - create
# - methods and opreations
#   -union
#   - intersection
#   - symmretric diffrences
#   - issubset
#   - issuperset

# %%
x = {1,2,3,4,5,3,4,5,7,2,45,7}
print(x)
# Out:
# {1, 2, 3, 4, 5, 7, 45}
